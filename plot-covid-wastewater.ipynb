# %%
import camelot
import pandas as pd
import altair as alt

# %%
df = camelot.read_pdf("https://www.mwra.com/biobot/MWRAData20211230-data.pdf", )[0].df
df.columns = df.iloc[0]
df = df.drop(0)
new_column_names = {name: name.replace("\n", "") for name in df.columns}
df = df.rename(columns=new_column_names)
df["Sample Date"] = pd.to_datetime(df["Sample Date"])
for col in df.columns:
    if col != "Sample Date":
        df[col] = pd.to_numeric(df[col])
df
# Out:
# 0  Sample Date  Southern (copies/mL)  Northern (copies/mL)  \
# 1   2020-03-01                   NaN                   NaN
# 2   2020-03-02                   NaN                   NaN
# 3   2020-03-03                   NaN                   NaN
# 4   2020-03-04                   NaN                   NaN
# 5   2020-03-05                   NaN                   NaN
# ..         ...                   ...                   ...
# 73  2020-05-12                   NaN                   NaN
# 74  2020-05-13                   NaN                   NaN
# 75  2020-05-14                   NaN                   NaN
# 76  2020-05-15                   NaN                   NaN
# 77  2020-05-16                   NaN                   NaN
#
# 0   Southern 7 day avg  Northern 7 day avg  Southern Low Confidence Interval  \
# 1                  NaN                 NaN                               NaN
# 2                  NaN                 NaN                               NaN
# 3                  NaN                 NaN                               NaN
# 4                  NaN                 NaN                               NaN
# 5                  NaN                 NaN                               NaN
# ..                 ...                 ...                               ...
# 73                29.0                22.0                               0.0
# 74                 NaN                 NaN                               0.0
# 75                 NaN                 NaN                               0.0
# 76                 NaN                 NaN                               0.0
# 77                 NaN                 NaN                               0.0
#
# 0   Southern High Confidence Interval  Northern Low Confidence Interval  \
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                                 NaN                               NaN
# 5                                 NaN                               NaN
# ..                                ...                               ...
# 73                                0.0                               0.0
# 74                                0.0                               0.0
# 75                                0.0                               0.0
# 76                                0.0                               0.0
# 77                                0.0                               0.0
#
# 0   Northern High Confidence Interval  Southern Variant Results  \
# 1                                 NaN                       NaN
# 2                                 NaN                       NaN
# 3                                 NaN                       NaN
# 4                                 NaN                       NaN
# 5                                 NaN                       NaN
# ..                                ...                       ...
# 73                                0.0                       NaN
# 74                                0.0                       NaN
# 75                                0.0                       NaN
# 76                                0.0                       NaN
# 77                                0.0                       NaN
#
# 0   Northern Variant Results
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# ..                       ...
# 73                       NaN
# 74                       NaN
# 75                       NaN
# 76                       NaN
# 77                       NaN
#
# [77 rows x 11 columns]

# %%
alt.Chart(df).mark_line().encode(x="Sample Date", y="Northern 7 day avg")
# Out:
# alt.Chart(...)
